# %%
import pandas as pd 
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("data/diabetes.csv")
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
## null check 
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.heatmap(df.corr(), annot=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 sns.heatmap(df.corr(), annot=True)
#       2 plt.show()
#
# NameError: name 'df' is not defined

# %%
plt.figure(figsize=(15, 5))
sns.boxplot(df)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 plt.figure(figsize=(15, 5))
# ----> 2 sns.boxplot(df)
#       3 plt.show()
#
# NameError: name 'df' is not defined

# %%
for col in df.drop(columns='Outcome').columns:
    sns.displot(data=df, x=col, kind='kde', hue='Outcome')

# %%
df['Outcome'].value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.shape
# Out:
# (768, 9)

# %%
df.to_csv("trained_data.csv", index=None)

# %%
X = df.drop(columns='Outcome')
y = df['Outcome']

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state=42)
X_smoted, y_smoted = smote.fit_resample(X, y)

# %%
X_smoted
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin        BMI  \
# 0              6      148             72             35        0  33.600000
# 1              1       85             66             29        0  26.600000
# 2              8      183             64              0        0  23.300000
# 3              1       89             66             23       94  28.100000
# 4              0      137             40             35      168  43.100000
# ..           ...      ...            ...            ...      ...        ...
# 995            5      164             64              0        0  31.906102
# 996            5      107             69             31        0  35.752773
# 997            4      171             83             27      154  33.300000
# 998            8      111             81             32      175  34.173097
# 999            4      144             79             32        0  37.428351
#
#      DiabetesPedigreeFunction  Age
# ...

# %%
X_smoted.shape
# Out:
# (1000, 8)

# %%
y_smoted.value_counts()
# Out:
# Outcome
# 1    500
# 0    500
# Name: count, dtype: int64

# %%
## train test split
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_smoted,y_smoted,
                                                   test_size=0.25,
                                                   random_state=42)

X_train.shape, X_test.shape
# Out:
# ((750, 8), (250, 8))

# %%
## transform the data
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
## save the scaler model
import pickle
pickle.dump(scaler, open("scaler.pkl", "wb"))

# %%
X_train_scaled
# Out:
# array([[ 9.76823464e-01, -1.29514748e+00,  4.30766733e-01, ...,
#         -4.70519085e-01,  8.02490997e-01,  1.99427572e-01],
#        [ 4.94594159e-02, -8.32139149e-01,  4.05377312e-03, ...,
#          5.52011590e-01,  1.11507076e+00, -4.20462749e-01],
#        [-2.59661933e-01,  8.03823617e-01,  9.64157932e-01, ...,
#          1.84090362e+00, -4.65518686e-01, -5.09018509e-01],
#        ...,
#        [-8.77904632e-01, -3.07396375e-01,  4.05377312e-03, ...,
#          2.42678845e-01,  4.51984340e-02, -1.54795469e-01],
#        [-1.18702598e+00,  4.95151397e-01, -3.72968462e+00, ...,
#          1.32503734e+00, -9.20943517e-01, -4.20462749e-01],
#        [-1.18702598e+00,  1.27584518e-03,  1.39087089e+00, ...,
#         -1.40256364e+00, -7.46146778e-01, -1.12890883e+00]])

# %%
## model training 
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier

## performance metrices
from sklearn.metrics import confusion_matrix, f1_score, accuracy_score, precision_score, recall_score, roc_auc_score

# %%
models = {
    "LogisticRegression": LogisticRegression(),
    "RandomForest": RandomForestClassifier(),
    "svm": SVC(),
    "DTree": DecisionTreeClassifier(),
    "GausianNB": GaussianNB(),
    "KNN": KNeighborsClassifier(),
    "GradientBoost": GradientBoostingClassifier()
}

for name, model in models.items():
    model.fit(X_train_scaled, y_train)

    ## prediction
    y_train_pred = model.predict(X_train_scaled)
    y_test_pred = model.predict(X_test_scaled)

    ### performace of the models
    print(f"\n==========={name}======================")
    print("Performace of the models for Training datasets")
    print("Accuracy",accuracy_score(y_train, y_train_pred))
    print("F1", f1_score(y_train, y_train_pred))
    print("Precision", precision_score(y_train, y_train_pred))
    print("Recall", recall_score(y_train, y_train_pred))
    print("ROC AUC", roc_auc_score(y_train, y_train_pred))
    print("Confusion Metrix\n", confusion_matrix(y_train, y_train_pred))

    print("Performance of the  model for test datasets")
    print("Accuracy",accuracy_score(y_test, y_test_pred))
    print("F1", f1_score(y_test, y_test_pred))
    print("Precision", precision_score(y_test, y_test_pred))
    print("Recall", recall_score(y_test, y_test_pred))
    print("ROC AUC", roc_auc_score(y_test, y_test_pred))
    print("Confusion Metrix\n", confusion_matrix(y_test, y_test_pred))
# Out:
# ===========LogisticRegression======================
# Performace of the models for Training datasets
# Accuracy 0.748
# F1 0.7400275103163686
# Precision 0.7620396600566572
# Recall 0.7192513368983957
# ROC AUC 0.7479235407896234
# Confusion Metrix
#  [[292  84]
#  [105 269]]
# Performance of the  model for test datasets
# Accuracy 0.76
# F1 0.7619047619047619
# Precision 0.7619047619047619
# Recall 0.7619047619047619
# ROC AUC 0.7599846390168971
# Confusion Metrix
#  [[94 30]
#  [30 96]]
#
# ===========RandomForest======================
# Performace of the models for Training datasets
# Accuracy 1.0
# F1 1.0
# Precision 1.0
# Recall 1.0
# ROC AUC 1.0
# Confusion Metrix
#  [[376   0]
#  [  0 374]]
# Performance of the  model for test datasets
# Accuracy 0.8
# F1 0.81203007518797
# Precision 0.7714285714285715
# Recall 0.8571428571428571
# ROC AUC 0.7995391705069125
# Confusion Metrix
#  [[ 92  32]
#  [ 18 108]]
#
# ===========svm======================
# ...

# %%
## Hyperparameter Training
rf_params = {"max_depth": [5, 8, 15, None, 10],
             "max_features": [5, 7, "auto", 8],
             "min_samples_split": [2, 8, 15, 20],
             "n_estimators": [100, 200, 500, 1000]}

gradiant_param = {
    "loss": ['log_loss', 'exponential'],
    "criterion": ['friedman_mse', 'squared_error'],
    "min_samples_split": [2, 8, 15, 20],
    "n_estimators": [100, 200 , 500, 1000],
    "max_depth": [5, 8, 15, None, 10]
}

logistic_param= {
    "penalty": ['l1', 'l2', 'elasticnet', None],
    "solver": ['lbfgs', 'liblinear', 'newton-cg', 'saga'],
    "max_iter":[100, 200, 300],
    "verbose": [1, 2, 3, 4]
}

# %%
# Models list for Hyperparameter tuning
randomcv_models = [
                ("RF", RandomForestClassifier(), rf_params),
                ('LogistceRege', LogisticRegression(), logistic_param),
                ("gradiantBoost", GradientBoostingClassifier(), gradiant_param)
                   ]

# %%
randomcv_models
# Out:
# [('RF',
#   RandomForestClassifier(),
#   {'max_depth': [5, 8, 15, None, 10],
#    'max_features': [5, 7, 'auto', 8],
#    'min_samples_split': [2, 8, 15, 20],
#    'n_estimators': [100, 200, 500, 1000]}),
#  ('LogistceRege',
#   LogisticRegression(),
#   {'penalty': ['l1', 'l2', 'elasticnet', None],
#    'solver': ['lbfgs', 'liblinear', 'newton-cg', 'saga'],
#    'max_iter': [100, 200, 300],
#    'verbose': [1, 2, 3, 4]}),
#  ('gradiantBoost',
#   GradientBoostingClassifier(),
#   {'loss': ['log_loss', 'exponential'],
#    'criterion': ['friedman_mse', 'squared_error'],
#    'min_samples_split': [2, 8, 15, 20],
#    'n_estimators': [100, 200, 500, 1000],
#    'max_depth': [5, 8, 15, None, 10]})]

# %%
from sklearn.model_selection import RandomizedSearchCV

model_param = {}
for name, model, params in randomcv_models:
    random = RandomizedSearchCV(estimator=model,
                                   param_distributions=params,
                                   n_iter=100,
                                   cv=3,
                                   verbose=2,
                                   n_jobs=-1)
    random.fit(X_train_scaled, y_train)
    model_param[name] = random.best_params_

for model_name in model_param:
    print(f"---------------- Best Params for {model_name} -------------------")
    print(model_param[model_name])
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[30], line 11
#       4 for name, model, params in randomcv_models:
#       5     random = RandomizedSearchCV(estimator=model,
#       6                                    param_distributions=params,
#       7                                    n_iter=100,
#       8                                    cv=3,
#       9                                    verbose=2,
#      10                                    n_jobs=-1)
# ---> 11     random.fit(X_train_scaled, y_train)
#      12     model_param[name] = random.best_params_
#      14 for model_name in model_param:
#
# File c:\Users\kamal\Desktop\projects\diabetes_prediction\myenv\lib\site-packages\sklearn\base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
# ...

# %%
models={
    
    "Random Forest":RandomForestClassifier(n_estimators=500,min_samples_split=8,
                                        max_features=8 ,max_depth=None),
    "GradiantBoost": GradientBoostingClassifier(n_estimators=1000, min_samples_split=8, max_depth=8, loss='log_loss', criterion='squared_error'),
    "LogisticReg": LogisticRegression(verbose=1, solver='newton-cg', penalty= 'l2', max_iter= 100)
}

for i in range(len(list(models))):
    model = list(models.values())[i]
    model.fit(X_train_scaled, y_train) # Train model

    # Make predictions
    y_train_pred = model.predict(X_train_scaled)
    y_test_pred = model.predict(X_test_scaled)

    # Training set performance
    model_train_accuracy = accuracy_score(y_train, y_train_pred) # Calculate Accuracy
    model_train_f1 = f1_score(y_train, y_train_pred, average='weighted') # Calculate F1-score
    model_train_precision = precision_score(y_train, y_train_pred) # Calculate Precision
    model_train_recall = recall_score(y_train, y_train_pred) # Calculate Recall
    model_train_rocauc_score = roc_auc_score(y_train, y_train_pred)


    # Test set performance
    model_test_accuracy = accuracy_score(y_test, y_test_pred) # Calculate Accuracy
    model_test_f1 = f1_score(y_test, y_test_pred, average='weighted') # Calculate F1-score
    model_test_precision = precision_score(y_test, y_test_pred) # Calculate Precision
    model_test_recall = recall_score(y_test, y_test_pred) # Calculate Recall
    model_test_rocauc_score = roc_auc_score(y_test, y_test_pred) #Calculate Roc


    print(list(models.keys())[i])
    
    print('Model performance for Training set')
    print("- Accuracy: {:.4f}".format(model_train_accuracy))
    print('- F1 score: {:.4f}'.format(model_train_f1))
    
    print('- Precision: {:.4f}'.format(model_train_precision))
    print('- Recall: {:.4f}'.format(model_train_recall))
    print('- Roc Auc Score: {:.4f}'.format(model_train_rocauc_score))
    print("Confusion Metrix\n", confusion_matrix(y_train, y_train_pred))

    
    
    print('----------------------------------')
    
    print('Model performance for Test set')
    print('- Accuracy: {:.4f}'.format(model_test_accuracy))
    print('- F1 score: {:.4f}'.format(model_test_f1))
    print('- Precision: {:.4f}'.format(model_test_precision))
    print('- Recall: {:.4f}'.format(model_test_recall))
    print('- Roc Auc Score: {:.4f}'.format(model_test_rocauc_score))
    print("Confusion Metrix\n", confusion_matrix(y_test, y_test_pred))

    
    print('='*35)
    print('\n')
# Out:
# Random Forest
# Model performance for Training set
# - Accuracy: 0.9773
# - F1 score: 0.9773
# - Precision: 0.9760
# - Recall: 0.9786
# - Roc Auc Score: 0.9773
# Confusion Metrix
#  [[367   9]
#  [  8 366]]
# ----------------------------------
# Model performance for Test set
# - Accuracy: 0.8080
# - F1 score: 0.8071
# - Precision: 0.7746
# - Recall: 0.8730
# - Roc Auc Score: 0.8075
# Confusion Metrix
#  [[ 92  32]
#  [ 16 110]]
# ...
#
#
# GradiantBoost
# Model performance for Training set
# - Accuracy: 1.0000
# - F1 score: 1.0000
# - Precision: 1.0000
# - Recall: 1.0000
# - Roc Auc Score: 1.0000
# Confusion Metrix
#  [[376   0]
#  [  0 374]]
# ----------------------------------
# Model performance for Test set
# - Accuracy: 0.7760
# - F1 score: 0.7756
# - Precision: 0.7574
# - Recall: 0.8175
# - Roc Auc Score: 0.7757
# Confusion Metrix
#  [[ 91  33]
#  [ 23 103]]
# ...
#
#
# LogisticReg
# Model performance for Training set
# - Accuracy: 0.7480
# - F1 score: 0.7478
# - Precision: 0.7620
# ...

# %%
rf = RandomForestClassifier(n_estimators=500,min_samples_split=8,
                                          max_features=8,max_depth=None)

rf.fit(X_train_scaled, y_train)
# Out:
# RandomForestClassifier(max_features=8, min_samples_split=8, n_estimators=500)

# %%
## save the model
import pickle
pickle.dump(rf, open("randomForest.pkl", 'wb'))

# %%
y_train_pred = rf.predict(X_train_scaled)
y_test_predict = rf.predict(X_test_scaled)

# %% [markdown]
# # Test model

# %%
## load model
model = pickle.load(open("randomForest.pkl", "rb"))
scaler_model = pickle.load(open("scaler.pkl", "rb"))

# %%
df.sample(5)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 85             2      110             74             29      125  32.4
# 331            2       87             58             16       52  32.7
# 709            2       93             64             32      160  38.0
# 303            5      115             98              0        0  52.9
# 724            1      111             94              0        0  32.8
#
#      DiabetesPedigreeFunction  Age  Outcome
# 85                      0.698   27        0
# 331                     0.166   25        0
# 709                     0.674   23        1
# 303                     0.209   28        1
# 724                     0.265   45        0

# %%
y_train.loc[82]
# Out:
# 0

# %%
input_data = X_train.loc[303]
input_data=input_data.values
input_data
# Out:
# array([  5.   , 115.   ,  98.   ,   0.   ,   0.   ,  52.9  ,   0.209,
#         28.   ])

# %%
scaled_data = scaler_model.transform([input_data])
scaled_data
# Out:
# array([[ 0.35858077, -0.30739637,  1.49754913, -1.34396163, -0.72644147,
#          2.76422378, -0.90867708, -0.50901851]])

# %%
prediction = model.predict(scaled_data)

# %%
prediction
# Out:
# array([1], dtype=int64)
